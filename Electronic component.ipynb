# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2316 try:
# -> 2317     module = self._get_module(self._class_to_module[name])
#    2318     value = getattr(module, name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2344 try:
# -> 2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
# ...

# %%
# ==========================================
# STEP 1: LOAD THE MODEL
# ==========================================
print("Loading Model... (This takes a few seconds)")
# We use 'all-MiniLM-L6-v2'. It's small, fast, and runs locally.
model = SentenceTransformer('all-MiniLM-L6-v2') 

# ==========================================
# STEP 2: PREPARE DATA (Simulating Excel)
# ==========================================
data = [
    {"component": "Resistor", "desc": "A passive component that limits the flow of current.", "category": "Passive"},
    {"component": "Capacitor", "desc": "Stores electrical energy in an electric field.", "category": "Passive"},
    {"component": "Diode", "desc": "Allows current to flow in only one direction.", "category": "Semiconductor"},
    {"component": "Transistor", "desc": "A semiconductor used to amplify or switch electrical signals.", "category": "Active"},
    {"component": "555 Timer", "desc": "An integrated circuit used for pulse generation and timing.", "category": "IC"},
    {"component": "LED", "desc": "Light Emitting Diode that emits light when current flows.", "category": "Optoelectronics"}
]

# Convert list to a Pandas DataFrame (like an Excel sheet)
df = pd.DataFrame(data)
print("\n--- DATABASE LOADED ---")
print(df[['component', 'desc']])

# ==========================================
# STEP 3: CREATE EMBEDDINGS
# ==========================================
print("\n--- CREATING EMBEDDINGS (Converting text to numbers) ---")
# This converts the 'desc' column into vectors
vectors = model.encode(df['desc'].tolist())
print("Embeddings created successfully.")

# ==========================================
# STEP 4: THE CHAIN (Search Function)
# ==========================================
def search_component(user_query):
    print(f"\n--- Processing Query: '{user_query}' ---")
    
    # 1. Embed the query
    query_vector = model.encode([user_query])
    
    # 2. Calculate similarity (Dot Product)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2316 try:
# -> 2317     module = self._get_module(self._class_to_module[name])
#    2318     value = getattr(module, name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2344 try:
# -> 2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
# ...
